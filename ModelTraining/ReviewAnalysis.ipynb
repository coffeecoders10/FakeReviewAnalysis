# %% [markdown]
# # IMPORTS

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.corpus import stopwords
from nltk import punkt
import random as r
import pymysql

# %% [markdown]
# # DATA

# %%
import csv

input_file = csv.DictReader(open("review_data_sentiment.csv",encoding='cp850'))
data = []
k = 0
for i in input_file:
    data.append(dict(i))

x = round(0.8*(len(data)))
data2 = data[:]

train_data = r.sample(data, x)
for i in train_data:
    data2.remove(i)
test_data = data2[:]

print("TRAIN DATA")
print(len(train_data))
print("TEST DATA")
print(len(test_data))
# type(input_file)
# Out:
# TRAIN DATA
# 21230
# TEST DATA
# 5308

# %% [markdown]
# # MODEL

# %%
class PreProcessReviews:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processReviews(self, list_of_reviews):
        processedReviews=[]
            
        for review in list_of_reviews:
            processedReviews.append((self._processReview(review["text"]),review["sentiment"]))
        return processedReviews
    
    def _processReview(self, review):
        review = review.lower() # convert text to lower-case
        review = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', review) # remove URLs
        review = re.sub('@[^\s]+', 'AT_USER', review) # remove usernames
        review = re.sub(r'#([^\s]+)', r'\1', review) # remove the # in #hashtag
        review = word_tokenize(review) # remove repeated characters (helloooooooo into hello)
        return [word for word in review if word not in self._stopwords]
    
reviewProcessor = PreProcessReviews()
preprocessedTrainingSet = reviewProcessor.processReviews(train_data)
print(preprocessedTrainingSet[0])
def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features
def extract_features(review):
    review_words = set(review)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in review_words)
    return features

word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)
print(trainingFeatures[:5])
print(word_features[:5])
# Out:
# (['bought', '3', 'different', 'micro', 'bluetooth', 'speakers', 'one', 'finished', 'close', 'first', 'place', 'get', 'quality', 'standpoint', 'speaker', 'one-quarter', 'price', 'speaker', 'rated', 'number', 'one', 'one', 'lasts', 'long', 'number', 'one', 'rated', 'speaker', 'one', 'far', 'best', 'value'], 'T')
# [({'contains(bought)': True, 'contains(3)': True, 'contains(different)': True, 'contains(micro)': True, 'contains(bluetooth)': True, 'contains(speakers)': True, 'contains(one)': True, 'contains(finished)': True, 'contains(close)': True, 'contains(first)': True, 'contains(place)': True, 'contains(get)': True, 'contains(quality)': True, 'contains(standpoint)': True, 'contains(speaker)': True, 'contains(one-quarter)': True, 'contains(price)': True, 'contains(rated)': True, 'contains(number)': True, 'contains(lasts)': True, 'contains(long)': True, 'contains(far)': True, 'contains(best)': True, 'contains(value)': True, 'contains(problem)': False, "contains(n't)": False, 'contains(little)': False, 'contains(molded)': False, 'contains(cover)': False, 'contains(button)': False, 'contains(top)': False, 'contains(iphone)': False, 'contains(design)': False, 'contains(flat)': False, 'contains(piece)': False, 'contains(squashes)': False, 'contains(basically)': False, 'contains(case)': False, 'contains(usable)': False, "contains('s)": False, 'contains(also)': False, 'contains(worth)': False, 'contains(returning)': False, 'contains(colors)': False, 'contains(true)': False, 'contains(bad)': False, 'contains(poor)': False, 'contains(ordered)': False, 'contains(t-mobile)': False, 'contains(lg)': False, 'contains(optimus)': False, 'contains(l9)': False, 'contains(knowing)': False, 'contains(sizes)': False, 'contains(got)': False, 'contains(big)': False, 'contains(bottom)': False, 'contains(cut)': False, 'contains(size)': False, 'contains(replacement)': False, 'contains(another)': False, 'contains(company)': False, 'contains(read)': False, 'contains(reviews)': False, 'contains(hand)': False, 'contains(gave)': False, 'contains(1)': False, 'contains(star)': False, 'contains(seller)': False, 'contains(say)': False, 'contains(international)': False, 'contains(version)': False, 'contains(hahaha)': False, 'contains(...)': False, 'contains(lol-ol-ol)': False, 'contains(35)': False, 'contains(.84)': False, 'contains(bag)': False, 'contains(straps)': False, 'contains(well)': False, 'contains(36th)': False, 'contains(time-well-spent)': False, 'contains(reviewer)': False, 'contains(lol)': False, 'contains(sorry)': False, 'contains(people)': False, 'contains(seriously)': False, 'contains(cares)': False, 'contains(know)': False, 'contains(hall)': False, 'contains(4x8)': False, 'contains(trailer)': False, 'contains(haha)': False, 'contains(10)': False, 'contains(tries)': False, 'contains(fail)': False, 'contains(buy)': False, 'contains(buying)': False, 'contains(bunch)': False, 'contains(tiny)': False, 'contains(usb)': False, 'contains(gifts)': False, 'contains(xmas)': False, 'contains(ran)': False, 'contains(comments)': False, 'contains(spent)': False, 'contains(15)': False, 'contains(mins)': False, 'contains(merry)': False, 'contains(junk)': False, 'contains(ended)': False, 'contains(going)': False, 'contains(purchase)': False, 'contains(sim)': False, 'contains(card)': False, 'contains(cost)': False, 'contains(nothing)': False, 'contains(phone)': False, 'contains(comes)': False, 'contains(w/)': False, 'contains(appstore)': False, 'contains(must)': False, 'contains(use)': False, 'contains(find)': False, 'contains(fundamental)': False, 'contains(things)': False, 'contains(would)': False, 'contains(expect)': False, 'contains(smart)': False, 'contains(add)': False, 'contains(times)': False, 'contains(stopwatches)': False, 'contains(notepads)': False, 'contains(etc.the)': False, 'contains(support)': False, 'contains(motorola)': False, 'contains(non-existent)': False, 'contains(want)': False, 'contains(anything)': False, 'contains(go)': False, 'contains(customer)': False, 'contains(focused)': False, 'contains(htc)': False, 'contains(backed)': False, 'contains(product)': False, 'contains(friends)': False, 'contains(samsung)': False, 'contains(does.there)': False, 'contains(much)': False, 'contains(better)': False, 'contains(alternatives-)': False, 'contains(stay)': ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-735a54b11cff> in <module>()
#      41 trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)
#      42 print(trainingFeatures[:5])
# ---> 43 print(word_features[:5])
#
# TypeError: 'dict_keys' object is not subscriptable

# %% [markdown]
# # SAVE WORD FEATURES

# %%
w = list(word_features)
with open('wordfeatures.txt', 'w') as f:
    for item in w:
        f.write("%s\n" % item)

# %% [markdown]
# # TRAINING

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)
print(NBayesClassifier)
# Out:
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x000000523C38AC18>

# %% [markdown]
# # SAVE MODEL

# %%
import pickle
f = open('NBClassifier_1', 'wb')
pickle.dump(NBayesClassifier, f)
f.close()

# %% [markdown]
# # TESTING

# %%
preprocessedTestingSet = reviewProcessor.processReviews(test_data)
test = []
result = []
for i in range(len(data)-x):
    t = r.choice(preprocessedTestingSet)
    preprocessedTestingSet.remove(t)
    test.append(t[0])
    result.append(t[1])
# print(test)
# print(result)
k = 0
p = 0
for i in test:
    NB = NBayesClassifier.classify(extract_features(i))
#     print(NB," ",result[k])
    if NB == result[k]:
        p = p + 1
    k = k + 1
accuracy = p*100/k
print("ACCURACY =")
print(accuracy)
# Out:
# ACCURACY =
# 84.8153730218538

# %% [markdown]
# # DATABASE

# %%
import pymysql
conn = pymysql.connect(host="localhost",user="root",passwd="",db="fake_feedback")
cur = conn.cursor()
print("Database Connected")

try:
    d = "select * from reviews"
    cur.execute(d)
    review_data = cur.fetchall()
#     print(data)
    neg = "select * from negative_words"
    cur.execute(neg)
    neg_words = cur.fetchall()
#     print(neg_words)
except Exception as e:
    print("ERROR=",e)
    
review = []
ip_addr = []
negatives = []

for i in review_data:
    review.append(i[2])
    ip_addr.append(i[1])

for i in neg_words:
    negatives.append(i[1])

me_list = ['i','me','myself','my','mine','us','we','our']

ln = ['.com','.org','.net','.gov']

# print(ip_addr)
# print(negatives)
# Out:
# Database Connected

# %% [markdown]
# # TO REMOVE PUNCTUATIONS

# %%
def remove_punc(s):
    # define punctuation
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    
    no_punct = ""
    for char in s:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct

# %% [markdown]
# # VERIFICATION

# %%
def verify_fake(ip,r):
    v = [0 for i in range(4)]
    r1 = remove_punc(r)
    rev1 = r1.split(" ")
    rev = [i.lower() for i in rev1]
    nc = 0
    myc = 0
    linkc = 0
    
    ipc = ip_addr.count(ip)
    for i in negatives:
        nc = nc + rev.count(i)
    myc = 0
    for i in me_list:
        myc = myc + rev.count(i)
    for i in r.split(" "):
        for j in ln:
            if j in i:
                linkc = linkc + 1
    if ipc > 1:
        v[0] = 1
    if nc > 3:
        v[1] = 1
    if myc > 4:
        v[2] = 1
    if linkc > 0:
        v[3] = 1

    return v

# %%
verify = ['Multiple reviews from same IP','Too many Negative Words','Self Promotion','Promotions via Links']

# %% [markdown]
# # IP GENERATION (FOR OFFLINE PURPOSES)

# %%
import random as r
def ip_generator():
    num = [i for i in range(255)]
    ip = str(r.choice(num))+"."+str(r.choice(num))+"."+str(r.choice(num))+"."+str(r.choice(num))
    return ip

# %% [markdown]
# # FAKE REVIEW DETECTION WITH ANALYSIS

# %%
import random as r
def review_detection(r_ip,ipr,model):
    result = ['','']
    fake_reasons = []
    
    if ipr == -1:
        return -1

    v = verify_fake(ipr,r_ip)
    if v.count(1)>=2:
        result[0] = 'FAKE'
    else:
        result[0] = 'NOT FAKE'
    for i in range(4):
        if v[i] == 1:
            fake_reasons.append(verify[i])
    
    preprocessedReview = reviewProcessor._processReview(r_ip)
    NB = model.classify(extract_features(preprocessedReview))
    
    if NB == 'T':
        result[1] = 'POSITIVE'
    elif NB == 'F':
        result[1] = 'NEGATIVE'
    else:
        result[1] = 'UNDEFINED'
    
    result.append(fake_reasons)
    
    return result

# %% [markdown]
# # LOAD MODEL

# %%
import pickle
f = open('NBClassifier_1', 'rb')
model = pickle.load(f)
f.close()

# %% [markdown]
# # EXAMPLE

# %%
r_ip = input('Enter Review:-')
ip_ip = int(input('0 for repeat ip; 1 for new ip:-'))

if ip_ip == 0:
    ipr = r.choice(ip_addr)
elif ip_ip == 1:
    ipr = ip_generator()
else: 
    print("Invalid option")
    ipr = -1

# print(ipr)

answer = review_detection(r_ip,ipr,model)

if answer == -1:
    print("ERROR")
else:
    print()
    print()
    print("REVIEW CLASSIFICATION:")
    print(answer[1])
    print(answer[0])
    print()
    if answer[0] == 'FAKE':
        print("REASONS:")
        for i in answer[2]:
            print(i)
    if answer[0] == 'NOT FAKE':
        print("RAISED RED FLAGS:")
        for i in answer[2]:
            print(i)
#     print(answer)
# Out:
# Enter Review:-Finger print very poor, can't function well apart from this there is Heating Problems. My phone is my, me I myself. use jhghjag.com
# 0 for repeat ip; 1 for new ip:-0
#
#
# REVIEW CLASSIFICATION:
# NEGATIVE
# FAKE
#
# REASONS:
# Multiple reviews from same IP
# Self Promotion
# Promotions via Links

# %%
# Very Nice Phone. Nice colour and Design. 6.5 inch screen makes a great viewing experience for movies and game's specialy PUBG. Super fast Charging. Full Charge in just 1.5 Hrs. But memory need to be 128 GB for this price range. Me me mine my visit aksjdgjksahd.com us we mine.
# Finger print very poor, can't function well apart from this there is Heating Problems
# Very Nice Phone. Nice colour and Design. 6.5 inch screen makes a great viewing experience for movies and game's specialy PUBG. Super fast Charging. Full Charge in just 1.5 Hrs. But memory need to be 128 GB for this price range.
